# %%
# !python pseudo_picky.py --tokenizer /Users/ahmetcanyavuz/Developer/tokenizers/results_50k/bpe_exact_ll/bpe_exact_ll-tokenizer.json --train /Users/ahmetcanyavuz/Developer/tokenizers/fineweb_data/fineweb_en_sentences.txt --mode count --count-threshold 10 --removal artifacts/token_removal_ios.json --verbose
# Out:
# [parents 00:30:11] Direct hits: 49799 | Split hits: 0 | Total parents: 49799 | Base tokens: 201 | Time=0.02s
# [init 00:30:11] Loaded tokenizer JSON in 0.08s
# [init] Vocab size: 50000 | #merges: 49799
# [init] Special tokens: 0
# [init] Parents coverage: 49799 / 50000 (99.6%)
# [init] Base tokens (derived): 201
# [init] Mode=count | Postprocess=split
#
# === BUILD REMOVALS ===
# [count 00:30:11] Counting token frequencies over: /Users/ahmetcanyavuz/Developer/tokenizers/fineweb_data/fineweb_en_sentences.txt
# [count] Encoded 10000 lines; unique tokens seen=9842
# [count] Encoded 20000 lines; unique tokens seen=13231
# [count] Encoded 30000 lines; unique tokens seen=15810
# [count] Encoded 40000 lines; unique tokens seen=17679
# [count] Encoded 50000 lines; unique tokens seen=19502
# [count] Encoded 60000 lines; unique tokens seen=20914
# [count] Encoded 70000 lines; unique tokens seen=22044
# [count] Encoded 80000 lines; unique tokens seen=23167
# ...

# %%
# !python pseudo_picky.py --tokenizer /Users/ahmetcanyavuz/Developer/tokenizers/results_50k/bpe_exact_ll/bpe_exact_ll-tokenizer.json --removal artifacts/token_removal_ios.json --postprocess split --text "There is candyland in Kentucky." --verbose
# Out:
# [parents 00:37:57] Direct hits: 49799 | Split hits: 0 | Total parents: 49799 | Base tokens: 201 | Time=0.02s
# [init 00:37:57] Loaded tokenizer JSON in 0.10s
# [init] Vocab size: 50000 | #merges: 49799
# [init] Special tokens: 0
# [init] Parents coverage: 49799 / 50000 (99.6%)
# [init] Base tokens (derived): 201
# [init] Mode=count | Postprocess=split
# [load_removals] Loaded 6781 removed tokens from artifacts/token_removal_ios.json in 0.01s
# [tokenize] Encoding text of length 31...
# [tokenize] Vanilla BPE produced 14 tokens in 0.005s
# [post/split] Start split-only for 14 tokens…
# [tokenize] Final tokens: 14 (Δ=0)
# TOKENS: ['ĠThere', 'Ġ', 'i', 's', 'Ġ', 'c', 'and', 'y', 'l', 'and', 'Ġ', 'in', 'ĠKentucky', '.']

# %%
# !python pseudo_picky.py --tokenizer /Users/ahmetcanyavuz/Developer/tokenizers/results_50k/bpe_exact_ll/bpe_exact_ll-tokenizer.json --removal artifacts/token_removal_ios.json --postprocess split --text "surviv" --verbose
# Out:
# [parents 00:38:03] Direct hits: 49799 | Split hits: 0 | Total parents: 49799 | Base tokens: 201 | Time=0.02s
# [init 00:38:03] Loaded tokenizer JSON in 0.09s
# [init] Vocab size: 50000 | #merges: 49799
# [init] Special tokens: 0
# [init] Parents coverage: 49799 / 50000 (99.6%)
# [init] Base tokens (derived): 201
# [init] Mode=count | Postprocess=split
# [load_removals] Loaded 6781 removed tokens from artifacts/token_removal_ios.json in 0.01s
# [tokenize] Encoding text of length 6...
# [tokenize] Vanilla BPE produced 1 tokens in 0.000s
# [post/split] Start split-only for 1 tokens…
# [tokenize] Final tokens: 4 (Δ=3)
# TOKENS: ['Ġ', 's', 'ur', 'viv']
